# %% [markdown]
# # In this notebook, we will learn the basics of TensorFlow.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.0

# %% [markdown]
# ## 创建一个Tensor

# %%
string = tf.Variable("This is a string", tf.string)
number = tf.Variable([3,2,4], tf.int16)
floating = tf.Variable(3.567, tf.float64)

print(number)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([3, 2, 4])>

# %%
rank1 = tf.Variable(["Test", "OK", "Pydoge"], tf.string)
rank2 = tf.Variable([["OK", "Pydoge"], ["Test", "Go"]], tf.string)

# %%
tf.rank(rank1)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
tf.rank(rank2)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
rank1.shape
# Out:
# TensorShape([3])

# %%
rank2.shape
# Out:
# TensorShape([2, 2])

# %% [markdown]
# ## 改变Tensor的形状

# %%
tensor1 = tf.ones([1,2,3])

# %%
tensor2 = tf.reshape(tensor1, [2,3,1])
tensor3 = tf.reshape(tensor2, [3,2,1])

# %%
print(tensor1)
print(tensor2)
# Out:
# tf.Tensor(
# [[[1. 1. 1.]
#   [1. 1. 1.]]], shape=(1, 2, 3), dtype=float32)
# tf.Tensor(
# [[[1.]
#   [1.]
#   [1.]]
#
#  [[1.]
#   [1.]
#   [1.]]], shape=(2, 3, 1), dtype=float32)
